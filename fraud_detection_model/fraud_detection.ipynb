# %%
print("hello")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'venv (3.14.0) (Python 3.14.0)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
